# %%
import pandas as pd

# %%
df=pd.read_csv('/content/preprocessing_practice_dataset.csv')

# %%
df.head()
# Out:
#    Employee_ID   Age  Gender Department  Education  Experience_Years  \
# 0         1001  59.0    Male         HR    Masters                18
# 1         1002  49.0  Female  Marketing  Bachelors                16
# 2         1003  35.0  Female         HR        NaN                19
# 3         1004  28.0  Female         HR        PhD                 9
# 4         1005  41.0    Male         IT  Bachelors                 5
#
#    Monthly_Salary  Performance_Rating        City Attrition
# 0         52350.0                   5     Calicut        No
# 1        118008.0                   2     Chennai       Yes
# 2        119297.0                   1       Kochi       Yes
# 3         50351.0                   2  Trivandrum       Yes
# 4        113668.0                   3  Trivandrum       Yes

# %%
df.isnull().sum()
# Out:
# Employee_ID            0
# Age                   10
# Gender                 0
# Department            10
# Education             10
# Experience_Years       0
# Monthly_Salary        10
# Performance_Rating     0
# City                  10
# Attrition              0
# dtype: int64

# %%
df['Age_mean_imputed']=df['Age'].fillna(df['Age'].mean())
df['Monthly_Salary_mean_imputed']=df['Monthly_Salary'].fillna(df['Monthly_Salary'].mean())
df['Department_mode_imputed']=df['Department'].fillna(df['Department'].mode()[0])
df['City_mode_imputed']=df['City'].fillna(df['City'].mode()[0])
df['Education_mode_imputed']=df['Education'].fillna(df['Education'].mode()[0])

# %%
df
# Out:
#     Employee_ID   Age  Gender Department  Education  Experience_Years  \
# 0          1001  59.0    Male         HR    Masters                18
# 1          1002  49.0  Female  Marketing  Bachelors                16
# 2          1003  35.0  Female         HR        NaN                19
# 3          1004  28.0  Female         HR        PhD                 9
# 4          1005  41.0    Male         IT  Bachelors                 5
# ..          ...   ...     ...        ...        ...               ...
# 95         1096  54.0  Female         HR    Masters                11
# 96         1097  53.0    Male  Marketing    Masters                13
# 97         1098  43.0    Male        NaN        PhD                 1
# 98         1099  44.0  Female  Marketing        PhD                18
# 99         1100  57.0  Female        NaN        NaN                17
#
#     Monthly_Salary  Performance_Rating        City Attrition  \
# 0          52350.0                   5     Calicut        No
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10,6))
sns.barplot(data=df,x="Age",y="Gender",palette='pastel')
plt.title("Age vs Gender")
plt.xlabel("Age")
plt.ylabel("Gender")
# Out:
# /tmp/ipykernel_1500/2455711245.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df,x="Age",y="Gender",palette='pastel')
# Text(0, 0.5, 'Gender')

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10,6))

sns.boxplot(data=df,x="Department",y="Experience_Years",palette='pastel')
plt.title("Department vs Experience")
plt.xlabel("Department")
plt.ylabel("Experience")
# Out:
# /tmp/ipykernel_1500/2226808283.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x="Department",y="Experience_Years",palette='pastel')
# Text(0, 0.5, 'Experience')

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10,6))
sns.lineplot(data=df,x="City",y="Gender",palette='pastel')
plt.title("City vs Gender")
plt.xlabel("City")
plt.ylabel("Gender")
# Out:
# /tmp/ipykernel_1500/1815571829.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df,x="City",y="Gender",palette='pastel')
# Text(0, 0.5, 'Gender')

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10,6))
sns.countplot(data=df,x="Department",palette='pastel')
plt.title("Department Distribution")
plt.xlabel("Department")
plt.ylabel("Count")
# Out:
# /tmp/ipykernel_1500/2258460987.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x="Department",palette='pastel')
# Text(0, 0.5, 'Count')

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10,6))
sns.histplot(data=df,x="Monthly_Salary",palette='pastel')
plt.title("Monthly Salary Distribution")
plt.xlabel("Monthly Salary")
plt.ylabel("Frequency")
# Out:
# /tmp/ipykernel_1500/380364875.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df,x="Monthly_Salary",palette='pastel')
# Text(0, 0.5, 'Frequency')

# %%
from sklearn.preprocessing import LabelEncoder
encoded_data=df.copy()
one_hot_encoded=pd.get_dummies(encoded_data['Department'],prefix="Department")
encoded_data=pd.concat([encoded_data,one_hot_encoded],axis=1)
encoded_data
# Out:
#     Employee_ID   Age  Gender Department  Education  Experience_Years  \
# 0          1001  59.0    Male         HR    Masters                18
# 1          1002  49.0  Female  Marketing  Bachelors                16
# 2          1003  35.0  Female         HR        NaN                19
# 3          1004  28.0  Female         HR        PhD                 9
# 4          1005  41.0    Male         IT  Bachelors                 5
# ..          ...   ...     ...        ...        ...               ...
# 95         1096  54.0  Female         HR    Masters                11
# 96         1097  53.0    Male  Marketing    Masters                13
# 97         1098  43.0    Male        NaN        PhD                 1
# 98         1099  44.0  Female  Marketing        PhD                18
# 99         1100  57.0  Female        NaN        NaN                17
#
#     Monthly_Salary  Performance_Rating        City Attrition  ...  \
# ...

# %%
performance_class={1:"one",2:"two",3:"three",4:"four",5:"five"}
encoded_data['Performance_Class']=encoded_data['Performance_Rating'].map(performance_class)
encoded_data
# Out:
#     Employee_ID   Age  Gender Department  Education  Experience_Years  \
# 0          1001  59.0    Male         HR    Masters                18
# 1          1002  49.0  Female  Marketing  Bachelors                16
# 2          1003  35.0  Female         HR        NaN                19
# 3          1004  28.0  Female         HR        PhD                 9
# 4          1005  41.0    Male         IT  Bachelors                 5
# ..          ...   ...     ...        ...        ...               ...
# 95         1096  54.0  Female         HR    Masters                11
# 96         1097  53.0    Male  Marketing    Masters                13
# 97         1098  43.0    Male        NaN        PhD                 1
# 98         1099  44.0  Female  Marketing        PhD                18
# 99         1100  57.0  Female        NaN        NaN                17
#
#     Monthly_Salary  Performance_Rating        City Attrition  ...  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
min_max_scaler=MinMaxScaler()
standard_scaler=StandardScaler()
encoded_data['Min_Max_Age']=min_max_scaler.fit_transform(encoded_data[['Age']])
encoded_data['standard_Salary']=standard_scaler.fit_transform(encoded_data[['Monthly_Salary']])
encoded_data
# Out:
#     Employee_ID   Age  Gender Department  Education  Experience_Years  \
# 0          1001  59.0    Male         HR    Masters                18
# 1          1002  49.0  Female  Marketing  Bachelors                16
# 2          1003  35.0  Female         HR        NaN                19
# 3          1004  28.0  Female         HR        PhD                 9
# 4          1005  41.0    Male         IT  Bachelors                 5
# ..          ...   ...     ...        ...        ...               ...
# 95         1096  54.0  Female         HR    Masters                11
# 96         1097  53.0    Male  Marketing    Masters                13
# 97         1098  43.0    Male        NaN        PhD                 1
# 98         1099  44.0  Female  Marketing        PhD                18
# 99         1100  57.0  Female        NaN        NaN                17
#
#     Monthly_Salary  Performance_Rating        City Attrition  ...  \
# ...
